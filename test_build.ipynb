# %% [markdown]
# # Libreta para probar funcionalidades / Notebook to test functionalities

# %% [markdown]
# ## 1. Imports

# %%
import subprocess

# %% [markdown]
# ## 2. AEMET Building

# %%
subprocess.run(['python', '-m', 'scripts.build_aemet'], check=True)
# Out:
# Fetching station data
# Saving station data
# Fetching AEMET data: 100%|██████████| 1340/1340 [01:16<00:00, 17.45it/s]
# Adding coordinates to weather data
# Saving weather data with coordinates
# Result:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7427530 entries, 0 to 7427529
# Data columns (total 27 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fecha        object
#  1   indicativo   object
#  2   nombre       object
#  3   provincia    object
#  4   altitud      int64
#  5   tmed         object
#  6   tmax         object
#  7   tmin         object
#  8   horatmax     object
#  9   horatmin     object
#  10  velmedia     object
#  11  racha        object
#  12  dir          float64
#  13  horaracha    object
#  14  hrMedia      float64
#  15  hrMax        float64
#  16  hrMin        float64
#  17  horaHrMax    object
#  18  horaHrMin    object
#  19  prec         object
#  20  sol          object
#  21  presMax      object
# ...

# %%
subprocess.run(['python', '-m', 'scripts.clean_aemet'], check=True)
# Out:
# Reading weather data
# Cleaning weather data
# Saving as parquet
# Adding completeness information to station dataframe
# Saving new information to csv
# Result:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7427530 entries, 0 to 7427529
# Data columns (total 40 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   fecha              datetime64[ns]
#  1   indicativo         category
#  2   nombre             category
#  3   provincia          category
#  4   tmed               float32
#  5   tmax               float32
#  6   tmin               float32
#  7   horatmax           float32
#  8   horatmin           float32
#  9   horatmaxVarias     int8
#  10  horatminVarias     int8
#  11  velmedia           float32
#  12  racha              float32
#  13  horaracha          float32
#  14  dir                float32
#  15  dirVarias          int8
#  16  hrMedia            float32
#  17  hrMax              float32
#  18  hrMin              float32
# ...

# %% [markdown]
# ## 3. ERA5 Building
#
# > Nota: la adquisición de datos se hizo antes, solo fue probada parcialmente aparte. No repito la adquisición de datos porque toma demasiado tiempo.

# %%
subprocess.run(['python', '-m', 'scripts.build_era5'], check=True)
# Out:
# ...
# Concatenating along time: 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
# CompletedProcess(args=['python', '-m', 'scripts.build_era5'], returncode=0)
